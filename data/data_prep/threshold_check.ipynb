# %% [markdown]
# Notebook to evaluate BraTS18 image data based on segmentation label ratios
#
# Goal is to filter out only samples above a cerain theshold.

# %%
import numpy as np
import os

# %%
# Replace 'your_folder_path' with the path to your folder
folder_path = 'npy/'

# valid files list
valid_image_list = []
# List all files in the folder
files = os.listdir(folder_path)

# Filter for .npy files
npy_files = [f for f in files if f.lower().endswith('.npy')]

# List to store the names of each valid file
valid_sample_brats = []
not_valid_sample_brats = []
file_names = []

# Loop through each .npy file
for npy_file in npy_files:
    # Load the .npy file
    file_path = os.path.join(folder_path, npy_file)
    image_array = np.load(file_path)

    # Extract the name without the extension
    file_name = os.path.splitext(npy_file)[0]
    
    # Append the name to the list
    file_names.append(file_name)

    # Optionally, print the array shape or perform other operations
    print(f'Loaded image: {file_name}')
    print(f'Image shape: {image_array.shape}')

    # count all elements of seg max and the individual labels
    counts = np.unique(image_array[4], return_counts=True)
    
    try:
        sum_total = np.sum(counts)

    
        count_1 = counts[1][1]
        count_2 = counts[1][2]
        count_3 = counts[1][3]

        # calculate ratio
        ratio_1 = count_1 / sum_total
        ratio_2 = count_2 / sum_total
        ratio_3 = count_3 / sum_total
        ratio_list = [ratio_1, ratio_2, ratio_3]

        # filter for threshold and append to list accordingly
        if ratio_1 > 0.0005 and ratio_2 > 0.0005 and ratio_3 > 0.0005:
            valid_sample_brats.append(file_name)
        else:
            not_valid_sample_brats.append(file_name)
    except:
        not_valid_sample_brats.append(file_name)
# Out:
# Loaded image: Brats18_2013_0_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_10_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_11_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_12_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_14_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_17_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_19_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_20_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_21_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_22_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_23_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_27_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_28_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_2_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_3_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_4_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_6_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_2013_7_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AAB_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AAG_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AAP_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ABE_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ABO_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ALN_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AME_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AMH_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ANG_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ANI_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ANZ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AOD_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AOO_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AOP_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AOZ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_APR_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_APY_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_APZ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQA_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQJ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQN_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQO_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQP_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQQ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQT_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQU_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQV_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQY_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AQZ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ARF_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ASA_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ASG_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ASN_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ASU_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ASV_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ASW_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ASY_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ATB_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ATF_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ATV_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_ATX_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AUN_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AUR_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AVJ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AVV_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AWG_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AWH_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AWI_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AXJ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AXL_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AXM_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AXN_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AXO_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AXQ_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_AYW_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_CBICA_BFB_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_180_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_186_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_201_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_203_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_235_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_335_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_378_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_390_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_401_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_412_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_429_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_448_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_460_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA01_499_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_117_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_118_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_151_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_168_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_222_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_274_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_290_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_300_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_314_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_321_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_368_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_370_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_374_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_377_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_394_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_430_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_455_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_471_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_491_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_606_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_607_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA02_608_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_121_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_138_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_257_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_265_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_296_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_375_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_419_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_474_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA03_498_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA04_149_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA04_328_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA04_361_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA04_479_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA05_277_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA05_396_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA05_444_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA05_478_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA06_165_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA06_184_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA06_211_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA06_247_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA06_332_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA06_372_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA06_409_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA06_603_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_105_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_162_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_167_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_205_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_242_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_278_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_319_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_436_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA08_469_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA09_141_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA10_152_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA10_241_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA10_261_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA10_408_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA10_410_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA10_490_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA13_623_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA13_642_1
# Image shape: (5, 155, 240, 240)
# Loaded image: Brats18_TCIA13_654_1
# Image shape: (5, 155, 240, 240)

# %%
print(len(valid_sample_brats))
print(len(not_valid_sample_brats))
print(valid_sample_brats[:5])
# Out:
# 154
# 0
# ['Brats18_2013_0_1', 'Brats18_2013_10_1', 'Brats18_2013_11_1', 'Brats18_2013_12_1', 'Brats18_2013_14_1']

# %%
# Loop through each filename in the not_valid_sample_brats list
for file_name in not_valid_sample_brats:
    # Construct the full file path with .npy extension
    file_path = os.path.join(folder_path, file_name + '.npy')
    
    # Check if the file exists before attempting to delete
    if os.path.exists(file_path):
        # Delete the file
        os.remove(file_path)
        print(f'Deleted file: {file_path}')
    else:
        print(f'File not found: {file_path}')

# %%
import os

folder_path = 'npy/'

# Paths to the list files
train_list_path = os.path.join(folder_path, 'train_list.txt')
valid_list_path = os.path.join(folder_path, 'valid_list.txt')

def update_list_file(file_path, entries_to_keep):
    """Keep only specified entries in a list file."""
    if not os.path.exists(file_path):
        print(f'{file_path} does not exist.')
        return

    # Read the existing entries from the file
    with open(file_path, 'r') as file:
        entries = [line.strip() for line in file]

    # Print existing entries for debugging
    print(f'Original entries in {file_path}:')
    print(entries)

    # Keep only entries that are in the valid_sample_brats list
    updated_entries = [entry for entry in entries if entry in entries_to_keep]

    # Print updated entries for debugging
    print(f'Updated entries for {file_path}:')
    print(updated_entries)

    # Write the updated entries back to the file
    with open(file_path, 'w') as file:
        for entry in updated_entries:
            file.write(entry + '\n')

    print(f'Updated {file_path}')

# Update train_list.txt and valid_list.txt
update_list_file(train_list_path, valid_sample_brats)
update_list_file(valid_list_path, valid_sample_brats)
# Out:
# Original entries in npy/train_list.txt:
# ['Brats18_CBICA_AOP_1', 'Brats18_TCIA02_168_1', 'Brats18_TCIA05_277_1', 'Brats18_2013_2_1', 'Brats18_TCIA08_242_1', 'Brats18_CBICA_ARZ_1', 'Brats18_CBICA_AQD_1', 'Brats18_TCIA04_437_1', 'Brats18_TCIA04_192_1', 'Brats18_CBICA_AME_1', 'Brats18_CBICA_ARF_1', 'Brats18_CBICA_AXM_1', 'Brats18_CBICA_AQZ_1', 'Brats18_CBICA_AQJ_1', 'Brats18_TCIA03_265_1', 'Brats18_CBICA_ABN_1', 'Brats18_TCIA02_322_1', 'Brats18_CBICA_ANZ_1', 'Brats18_CBICA_ABO_1', 'Brats18_CBICA_AYU_1', 'Brats18_TCIA03_375_1', 'Brats18_TCIA06_372_1', 'Brats18_TCIA08_162_1', 'Brats18_CBICA_AQN_1', 'Brats18_2013_12_1', 'Brats18_CBICA_ASO_1', 'Brats18_TCIA02_605_1', 'Brats18_CBICA_AVJ_1', 'Brats18_TCIA02_471_1', 'Brats18_CBICA_AMH_1', 'Brats18_TCIA02_606_1', 'Brats18_TCIA01_448_1', 'Brats18_TCIA01_150_1', 'Brats18_CBICA_AQP_1', 'Brats18_CBICA_AQV_1', 'Brats18_TCIA02_430_1', 'Brats18_2013_7_1', 'Brats18_CBICA_AUN_1', 'Brats18_CBICA_AVV_1', 'Brats18_2013_20_1', 'Brats18_TCIA02_374_1', 'Brats18_2013_13_1', 'Brats18_TCIA05_396_1', 'Brats18_CBICA_ASW_1', 'Brats18_TCIA02_283_1', 'Brats18_TCIA03_338_1', 'Brats18_TCIA01_231_1', 'Brats18_CBICA_ASY_1', 'Brats18_TCIA08_105_1', 'Brats18_TCIA02_607_1', 'Brats18_TCIA03_133_1', 'Brats18_2013_18_1', 'Brats18_TCIA03_199_1', 'Brats18_TCIA04_149_1', 'Brats18_TCIA08_113_1', 'Brats18_TCIA08_280_1', 'Brats18_CBICA_ALX_1', 'Brats18_CBICA_AXN_1', 'Brats18_2013_3_1', 'Brats18_CBICA_AWI_1', 'Brats18_CBICA_ASE_1', 'Brats18_CBICA_ASU_1', 'Brats18_CBICA_ALU_1', 'Brats18_TCIA01_335_1', 'Brats18_TCIA04_361_1', 'Brats18_TCIA06_211_1', 'Brats18_TCIA01_203_1', 'Brats18_TCIA08_319_1', 'Brats18_2013_17_1', 'Brats18_TCIA08_218_1', 'Brats18_CBICA_AOD_1', 'Brats18_TCIA02_118_1', 'Brats18_CBICA_AYA_1', 'Brats18_TCIA08_234_1', 'Brats18_CBICA_AOH_1', 'Brats18_TCIA01_221_1', 'Brats18_CBICA_AQQ_1', 'Brats18_TCIA03_121_1', 'Brats18_TCIA01_131_1', 'Brats18_CBICA_BFP_1', 'Brats18_TCIA01_186_1', 'Brats18_CBICA_BHB_1', 'Brats18_TCIA01_201_1', 'Brats18_TCIA01_425_1', 'Brats18_CBICA_ABY_1', 'Brats18_TCIA01_390_1', 'Brats18_CBICA_AZH_1', 'Brats18_TCIA06_247_1', 'Brats18_2013_11_1', 'Brats18_CBICA_AXO_1', 'Brats18_CBICA_AAP_1', 'Brats18_CBICA_AQG_1', 'Brats18_TCIA01_429_1', 'Brats18_TCIA02_226_1', 'Brats18_TCIA02_171_1', 'Brats18_CBICA_AOZ_1', 'Brats18_TCIA06_332_1', 'Brats18_CBICA_ATD_1', 'Brats18_2013_27_1', 'Brats18_CBICA_AAL_1', 'Brats18_TCIA02_198_1', 'Brats18_CBICA_ARW_1', 'Brats18_CBICA_AQY_1', 'Brats18_CBICA_AQU_1', 'Brats18_TCIA01_460_1', 'Brats18_TCIA04_111_1', 'Brats18_TCIA05_478_1', 'Brats18_CBICA_APR_1', 'Brats18_CBICA_AYW_1', 'Brats18_CBICA_AZD_1', 'Brats18_2013_25_1', 'Brats18_CBICA_AAB_1', 'Brats18_TCIA02_208_1', 'Brats18_TCIA02_222_1', 'Brats18_CBICA_APZ_1', 'Brats18_CBICA_AUR_1', 'Brats18_TCIA03_419_1', 'Brats18_TCIA08_278_1', 'Brats18_CBICA_AWH_1', 'Brats18_TCIA02_300_1', 'Brats18_CBICA_AXQ_1', 'Brats18_TCIA02_135_1', 'Brats18_2013_26_1', 'Brats18_CBICA_APY_1', 'Brats18_2013_21_1', 'Brats18_TCIA06_165_1', 'Brats18_CBICA_AAG_1', 'Brats18_2013_10_1', 'Brats18_TCIA02_309_1', 'Brats18_TCIA02_377_1', 'Brats18_TCIA06_603_1', 'Brats18_CBICA_BHK_1', 'Brats18_TCIA03_474_1', 'Brats18_2013_14_1', 'Brats18_2013_23_1', 'Brats18_TCIA08_469_1', 'Brats18_TCIA02_370_1', 'Brats18_TCIA03_296_1', 'Brats18_CBICA_ANI_1', 'Brats18_2013_19_1', 'Brats18_TCIA01_411_1', 'Brats18_TCIA02_314_1', 'Brats18_TCIA02_368_1', 'Brats18_CBICA_AOO_1', 'Brats18_TCIA01_235_1', 'Brats18_TCIA03_257_1', 'Brats18_CBICA_ASH_1', 'Brats18_CBICA_ASN_1', 'Brats18_TCIA01_147_1', 'Brats18_CBICA_AXW_1', 'Brats18_TCIA03_138_1', 'Brats18_CBICA_AWG_1', 'Brats18_TCIA02_491_1', 'Brats18_CBICA_ALN_1', 'Brats18_CBICA_AQT_1', 'Brats18_TCIA06_184_1', 'Brats18_CBICA_ATB_1', 'Brats18_CBICA_AUQ_1', 'Brats18_TCIA02_321_1', 'Brats18_TCIA08_406_1', 'Brats18_TCIA04_328_1', 'Brats18_CBICA_ATP_1', 'Brats18_CBICA_ASK_1', 'Brats18_CBICA_ABM_1', 'Brats18_2013_4_1', 'Brats18_TCIA02_151_1', 'Brats18_TCIA05_444_1', 'Brats18_CBICA_AQA_1', 'Brats18_TCIA10_640_1', 'Brats18_2013_28_1', 'Brats18_TCIA10_325_1', 'Brats18_2013_9_1', 'Brats ...
# Updated entries for npy/train_list.txt:
# ['Brats18_CBICA_AOP_1', 'Brats18_TCIA02_168_1', 'Brats18_TCIA05_277_1', 'Brats18_2013_2_1', 'Brats18_TCIA08_242_1', 'Brats18_CBICA_AME_1', 'Brats18_CBICA_ARF_1', 'Brats18_CBICA_AXM_1', 'Brats18_CBICA_AQZ_1', 'Brats18_CBICA_AQJ_1', 'Brats18_TCIA03_265_1', 'Brats18_CBICA_ANZ_1', 'Brats18_CBICA_ABO_1', 'Brats18_TCIA03_375_1', 'Brats18_TCIA06_372_1', 'Brats18_TCIA08_162_1', 'Brats18_CBICA_AQN_1', 'Brats18_2013_12_1', 'Brats18_CBICA_AVJ_1', 'Brats18_TCIA02_471_1', 'Brats18_CBICA_AMH_1', 'Brats18_TCIA02_606_1', 'Brats18_TCIA01_448_1', 'Brats18_CBICA_AQP_1', 'Brats18_CBICA_AQV_1', 'Brats18_TCIA02_430_1', 'Brats18_2013_7_1', 'Brats18_CBICA_AUN_1', 'Brats18_CBICA_AVV_1', 'Brats18_2013_20_1', 'Brats18_TCIA02_374_1', 'Brats18_TCIA05_396_1', 'Brats18_CBICA_ASW_1', 'Brats18_CBICA_ASY_1', 'Brats18_TCIA08_105_1', 'Brats18_TCIA02_607_1', 'Brats18_TCIA04_149_1', 'Brats18_CBICA_AXN_1', 'Brats18_2013_3_1', 'Brats18_CBICA_AWI_1', 'Brats18_CBICA_ASU_1', 'Brats18_TCIA01_335_1', 'Brats18_TCIA04_361_1', 'Brats18_TCIA06_211_1', 'Brats18_TCIA01_203_1', 'Brats18_TCIA08_319_1', 'Brats18_2013_17_1', 'Brats18_CBICA_AOD_1', 'Brats18_TCIA02_118_1', 'Brats18_CBICA_AQQ_1', 'Brats18_TCIA03_121_1', 'Brats18_TCIA01_186_1', 'Brats18_TCIA01_201_1', 'Brats18_TCIA01_390_1', 'Brats18_TCIA06_247_1', 'Brats18_2013_11_1', 'Brats18_CBICA_AXO_1', 'Brats18_CBICA_AAP_1', 'Brats18_TCIA01_429_1', 'Brats18_CBICA_AOZ_1', 'Brats18_TCIA06_332_1', 'Brats18_2013_27_1', 'Brats18_CBICA_AQY_1', 'Brats18_CBICA_AQU_1', 'Brats18_TCIA01_460_1', 'Brats18_TCIA05_478_1', 'Brats18_CBICA_APR_1', 'Brats18_CBICA_AYW_1', 'Brats18_CBICA_AAB_1', 'Brats18_TCIA02_222_1', 'Brats18_CBICA_APZ_1', 'Brats18_CBICA_AUR_1', 'Brats18_TCIA03_419_1', 'Brats18_TCIA08_278_1', 'Brats18_CBICA_AWH_1', 'Brats18_TCIA02_300_1', 'Brats18_CBICA_AXQ_1', 'Brats18_CBICA_APY_1', 'Brats18_2013_21_1', 'Brats18_TCIA06_165_1', 'Brats18_CBICA_AAG_1', 'Brats18_2013_10_1', 'Brats18_TCIA02_377_1', 'Brats18_TCIA06_603_1', 'Brats18_TCIA03_474_1', 'Brats18_2013_14_1', 'Brats18_2013_23_1', 'Brats18_TCIA08_469_1', 'Brats18_TCIA02_370_1', 'Brats18_TCIA03_296_1', 'Brats18_CBICA_ANI_1', 'Brats18_2013_19_1', 'Brats18_TCIA02_314_1', 'Brats18_TCIA02_368_1', 'Brats18_CBICA_AOO_1', 'Brats18_TCIA01_235_1', 'Brats18_TCIA03_257_1', 'Brats18_CBICA_ASN_1', 'Brats18_TCIA03_138_1', 'Brats18_CBICA_AWG_1', 'Brats18_TCIA02_491_1', 'Brats18_CBICA_ALN_1', 'Brats18_CBICA_AQT_1', 'Brats18_TCIA06_184_1', 'Brats18_CBICA_ATB_1', 'Brats18_TCIA02_321_1', 'Brats18_TCIA04_328_1', 'Brats18_2013_4_1', 'Brats18_TCIA02_151_1', 'Brats18_TCIA05_444_1', 'Brats18_CBICA_AQA_1', 'Brats18_2013_28_1', 'Brats18_TCIA10_261_1', 'Brats18_TCIA09_141_1', 'Brats18_TCIA10_152_1', 'Brats18_TCIA13_654_1', 'Brats18_TCIA10_241_1', 'Brats18_TCIA10_490_1', 'Brats18_TCIA13_623_1']
# Updated npy/train_list.txt
# Original entries in npy/valid_list.txt:
# ['Brats18_CBICA_AYI_1', 'Brats18_TCIA06_409_1', 'Brats18_CBICA_BHM_1', 'Brats18_2013_22_1', 'Brats18_CBICA_ASG_1', 'Brats18_TCIA02_117_1', 'Brats18_TCIA01_412_1', 'Brats18_CBICA_BFB_1', 'Brats18_TCIA08_205_1', 'Brats18_CBICA_ATF_1', 'Brats18_TCIA01_401_1', 'Brats18_CBICA_AXL_1', 'Brats18_TCIA02_331_1', 'Brats18_CBICA_AQR_1', 'Brats18_TCIA01_499_1', 'Brats18_CBICA_ANG_1', 'Brats18_CBICA_ASV_1', 'Brats18_TCIA08_436_1', 'Brats18_CBICA_ABB_1', 'Brats18_TCIA02_473_1', 'Brats18_CBICA_ASA_1', 'Brats18_TCIA02_179_1', 'Brats18_TCIA04_343_1', 'Brats18_TCIA02_394_1', 'Brats18_CBICA_ANP_1', 'Brats18_CBICA_ATV_1', 'Brats18_CBICA_ABE_1', 'Brats18_2013_5_1', 'Brats18_TCIA03_498_1', 'Brats18_CBICA_AVG_1', 'Brats18_TCIA01_378_1', 'Brats18_TCIA02_290_1', 'Brats18_TCIA04_479_1', 'Brats18_CBICA_AXJ_1', 'Brats18_TCIA01_180_1', 'Brats18_CBICA_ATX_1', 'Brats18_TCIA02_455_1', 'Brats18_TCIA02_608_1', 'Brats18_CBICA_AQO_1', 'Brats18_TCIA02_274_1', 'Brats18_TCIA08_167_1', 'Brats18_TCIA01_190_1', 'Brats18_TCIA13_624_1', 'Brats18_TCIA10_307_1', 'Brats18_2013_6_1', 'Brats18_TCIA13_642_1', 'Brats18_2013_15_1', 'Brats18_TCIA09_177_1', 'Brats18_TCIA10_632_1', 'Brats18_2013_0_1', 'Brats18_TCIA13_618_1', 'Brats18_TCIA10_410_1', 'Brats18_TCIA10_282_1', 'Brats18_TCIA10_408_1', 'Brats18_TCIA10_442_1', 'Brats18_TCIA10_644_1', 'Brats18_2013_24_1']
# Updated entries for npy/valid_list.txt:
# ['Brats18_TCIA06_409_1', 'Brats18_2013_22_1', 'Brats18_CBICA_ASG_1', 'Brats18_TCIA02_117_1', 'Brats18_TCIA01_412_1', 'Brats18_CBICA_BFB_1', 'Brats18_TCIA08_205_1', 'Brats18_CBICA_ATF_1', 'Brats18_TCIA01_401_1', 'Brats18_CBICA_AXL_1', 'Brats18_TCIA01_499_1', 'Brats18_CBICA_ANG_1', 'Brats18_CBICA_ASV_1', 'Brats18_TCIA08_436_1', 'Brats18_CBICA_ASA_1', 'Brats18_TCIA02_394_1', 'Brats18_CBICA_ATV_1', 'Brats18_CBICA_ABE_1', 'Brats18_TCIA03_498_1', 'Brats18_TCIA01_378_1', 'Brats18_TCIA02_290_1', 'Brats18_TCIA04_479_1', 'Brats18_CBICA_AXJ_1', 'Brats18_TCIA01_180_1', 'Brats18_CBICA_ATX_1', 'Brats18_TCIA02_455_1', 'Brats18_TCIA02_608_1', 'Brats18_CBICA_AQO_1', 'Brats18_TCIA02_274_1', 'Brats18_TCIA08_167_1', 'Brats18_2013_6_1', 'Brats18_TCIA13_642_1', 'Brats18_2013_0_1', 'Brats18_TCIA10_410_1', 'Brats18_TCIA10_408_1']
# Updated npy/valid_list.txt

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(len(updated_entries))
#
# NameError: name 'updated_entries' is not defined
